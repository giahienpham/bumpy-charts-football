# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mplsoccer
import highlight_text
from mplsoccer import Bumpy
from PIL import Image
from io import BytesIO
import requests

# %%
df = pd.read_csv('La Liga.csv')

# %%
df.head()
# Out:
#               Team  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  Week 7  \
# 0           Alaves      14      18      19      20      17      19      15
# 1    Athletic Club      16      19      14      15      19      14      16
# 2  Atletico Madrid       4       4       2       5       5       4       3
# 3        Barcelona       1       1       1       1       1       1       5
# 4            Cadiz      18      11      15      10      10       8       7
#
#    Week 8  Week 9  ...  Week 25  Week 26  Week 27  Week 28  Week 29  Week 30  \
# 0      15      15  ...       18       19       18       19       20       19
# 1      13      14  ...       10        8       11        9       10       11
# 2       2       1  ...        1        1        1        1        1        1
# 3       6       5  ...        2        2        2        2        2        3
# 4       7       7  ...       15       14       14       15       13       12
#
#    Week 31  Week 32  Week 33  Week 34
# ...

# %%
df = df.T

# %%
df.head()
# Out:
#             0              1                2          3      4           5   \
# Team    Alaves  Athletic Club  Atletico Madrid  Barcelona  Cadiz  Celta Vigo
# Week 1      14             16                4          1     18          12
# Week 2      18             19                4          1     11           7
# Week 3      19             14                2          1     15           8
# Week 4      20             15                5          1     10          12
#
#            6      7       8        9       10       11       12          13  \
# Team    Eibar  Elche  Getafe  Granada  Huesca  Levante  Osasuna  Real Betis
# Week 1     13     20      19        6      11       15        5           7
# Week 2     14     20      12        2      17       15        9           3
# Week 3     18     20      11        6      17       10       13           5
# Week 4     19     17       7        4      14       13       16           9
#
# ...

# %%
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df.head()
# Out:
# Team   Alaves Athletic Club Atletico Madrid Barcelona Cadiz Celta Vigo Eibar  \
# Week 1     14            16               4         1    18         12    13
# Week 2     18            19               4         1    11          7    14
# Week 3     19            14               2         1    15          8    18
# Week 4     20            15               5         1    10         12    19
# Week 5     17            19               5         1    10         13    14
#
# Team   Elche Getafe Granada Huesca Levante Osasuna Real Betis Real Madrid  \
# Week 1    20     19       6     11      15       5          7           3
# Week 2    20     12       2     17      15       9          3           5
# Week 3    20     11       6     17      10      13          5           3
# Week 4    17      7       4     14      13      16          9           2
# Week 5    18     11       4     15      16      12          6           2
#
# ...

# %%
week = ['Week ' + str(num) for num in range (1, 35)]

# %%
highlight_dict = {
    'Atletico Madrid' : '#CB3524',
    'Real Madrid': 'white',
    'Barcelona': '#EDBB00',
    'Sevilla':'green',
}

# %%
bumpy = Bumpy(
    scatter_color = '#282828',
    line_color = '#252525',
    rotate_xticks = 90,
    ticklabel_size = 15,
    scatter_primary = 'D',
    show_right = True,
    plot_labels = True,
    alignment_yvalue = .1,
    alignment_xvalue = .065 
)

# %%
fig, ax = bumpy.plot(
    x_list = week,
    y_list = np.linspace(1,20,20).astype(int),
    values = df,
    secondary_alpha= .5,
    highlight_dict = highlight_dict,
    figsize = (18, 18),
    # y_label = 'Position',
    ylim = (-.1,23),
    lw = 2.5
)

ax.set_ylabel('Position', labelpad=20) 

fig.text(s= 'La Liga through week 34', x = .17, y = .84,
         c = 'white', size = 24, weight = 'bold'
         )
highlight_text.fig_text(x=.17, y = .82,
                        s = 'Comparing <Atletico>, <Real Madrid>, <Barcelona> & <Sevilla>', highlight_textprops = [
                            {'color': '#CB3524'},
                            {'color': 'white'},
                            {'color': '#EDBB00'},
                            {'color': 'green'}
                        ], color = 'white', size = 16)

ax2 = fig.add_axes([.05,.77,.1,.2])
ax2.axis('off')
img = Image.open('logo.jpg')
ax2.imshow(img)
